# %%
# !pip install google.generativeai
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 1.7 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.8 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.8 MB 1.9 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/12.8 MB 1.5 MB/s eta 0:00:08
# ...

# %%
import os
import google.generativeai as genai

genai.configure(api_key="AIzaSyD29fRTL6uI4C0nhJIbM-JCFQkkB_iKuPg")

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-2.0-flash-exp",
  generation_config=generation_config,
)
def GenerateResponse(input_text):
    response = model.generate_content([
        "input: who are you",
        "output: I am a water leakage detection based chatbot",
        "input: What all can you do?",
        "output: I can help you with water leakage problems that you might be facing! How can I help?",
        f"input: {input_text}",
        "output: ",
    ])
    return response.text

while True:
    string=str(input("Enter your prompt:"))
    print(GenerateResponse(string))
# Out:
# Enter your prompt: How to detect water leakage in pipes?
# There are several ways to detect water leakage in pipes, here are some common methods:
#
# **1. Visual Inspection:**
#
# *   **Look for damp spots:** Check walls, ceilings, floors, and the ground around pipes for any signs of dampness, discoloration, or mold growth.
# *   **Observe for dripping or running water:** Listen for the sound of dripping or running water, especially when no water fixtures are in use.
# *   **Check for pooling water:** Look for puddles of water in unusual places, particularly near pipes or fixtures.
# *   **Examine exposed pipes:** Inspect exposed pipes for any signs of corrosion, cracks, or loose connections.
#
# **2. Water Meter Reading:**
#
# *   **Take an initial reading:** Turn off all water-using appliances and fixtures.
# *   **Record the current meter reading:** Note the numbers on your water meter.
# ...
